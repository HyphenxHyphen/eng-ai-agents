# %% [markdown]
# I am using Colab for now because my computer does not have enough disk space to install Docker, VS Code, and Linux.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/
# !git clone https://github.com/pantelis/eng-ai-agents.git
# Out:
# /content/drive/MyDrive
# Cloning into 'eng-ai-agents'...
# remote: Enumerating objects: 686, done.
# remote: Counting objects: 100% (118/118), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 686 (delta 73), reused 78 (delta 58), pack-reused 568 (from 3)
# Receiving objects: 100% (686/686), 1.44 MiB | 7.35 MiB/s, done.
# Resolving deltas: 100% (291/291), done.
# Updating files: 100% (108/108), done.

# %%
import torch

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
if torch.cuda.is_available():
    print(torch.cuda.current_device())
    print(torch.cuda.device_count())
    print(torch.cuda.get_device_name(0))

device
# Out:
# 0
# 1
# Tesla T4
# device(type='cuda', index=0)
